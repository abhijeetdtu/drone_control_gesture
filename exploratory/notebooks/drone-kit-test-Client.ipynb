# %%
import socket
import time

# %%
host = 'localhost'
port = 42425
s = socket.socket()
s.connect((host,port))

# %%
for i in range(100):
    time.sleep(0.25)
    s.send("NEXT_STATE".encode("utf-8"))
    data = s.recv(1024)
    print(data)
# Out:
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'
# b'LEFT'

# %%
s.close()
